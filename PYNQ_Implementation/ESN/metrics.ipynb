# %%
import time
import numpy as np
from pynq import Overlay, allocate  # <--- FIXED: Added 'allocate'

# 1. Setup
ol = Overlay("design_1.bit")
dma = ol.axi_dma_0

# Define sizes
N_OUTPUTS = 100000
input_buffer = allocate(shape=(1000,), dtype=np.int32)
output_buffer = allocate(shape=(N_OUTPUTS,), dtype=np.int32)

# 2. Measurement Loop
# Note: 32 bits per integer * N_OUTPUTS
DATA_SIZE_BITS = N_OUTPUTS * 32  
start_time = time.time()

# Trigger the transfer
dma.sendchannel.transfer(input_buffer)
dma.recvchannel.transfer(output_buffer)

# Wait for completion
dma.sendchannel.wait()
dma.recvchannel.wait()

end_time = time.time()

# 3. Calculation
duration = end_time - start_time
throughput_bps = DATA_SIZE_BITS / duration
throughput_gbps = throughput_bps / 1e9

print(f"Data Generated: {DATA_SIZE_BITS / 8 / 1024:.2f} KB")
print(f"Time Taken:     {duration:.4f} s")
print(f"Throughput:     {throughput_gbps:.4f} Gbps")

# 4. Cleanup (Good practice)
del input_buffer
del output_buffer
# Out:
# ERROR: Unknown command: 'dump'
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       3 from pynq import Overlay, allocate  # <--- FIXED: Added 'allocate'
#       5 # 1. Setup
# ----> 6 ol = Overlay("design_1.bit")
#       7 dma = ol.axi_dma_0
#       9 # Define sizes
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/overlay.py:336, in Overlay.__init__(self, bitfile_name, dtbo, download, ignore_version, device)
#     310 def __init__(self, bitfile_name, dtbo=None,
#     311              download=True, ignore_version=False, device=None):
#     312     """Return a new Overlay object.
#     313
#     314     An overlay instantiates a bitstream object as a member initially.
#    (...)
#     334
#     335     """
# --> 336     super().__init__(bitfile_name, dtbo, partial=False, device=device)
#     338     self._register_drivers()
#     340     self.parser = self.device.get_bitfile_metadata(self.bitfile_name)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/bitstream.py:137, in Bitstream.__init__(self, bitfile_name, dtbo, partial, device)
#     135     self.bitfile_name = bitfile_overlay_abs_lst[0]
#     136 else:
# --> 137     raise IOError('Bitstream file {} does not exist.'.format(
#     138         bitfile_name))
#     140 if bitfile_abs and bitfile_overlay_abs_lst or \
#     141         len(bitfile_overlay_abs_lst) > 1:
#     142     msg = ("The provided name '{}' resulted in multiple possible "
#     143            "matches:\n - ".format(bitfile_name))
#
# OSError: Bitstream file design_1.bit does not exist.

# %%
from pynq import get_rails

rails = get_rails()

# Read power from the main 5V rail (which powers the whole board)
voltage = rails['5V'].voltage
current = rails['5V'].current
power   = rails['5V'].power

print(f"Voltage: {voltage:.2f} V")
print(f"Current: {current:.2f} A")
print(f"Real-Time Power: {power:.2f} W")
